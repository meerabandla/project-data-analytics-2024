# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# %% [markdown]
# # Read all 3 datasets
#
# Crimes in Denmark till 2009 ,
# Crimes in Denmark till 2019 part1 , and
# Crimes in Denmark till 2019 part2

# %%
df_old=
df_new_part1=
df_new_part2=

# %% [markdown]
# ## check the data , Concat and Merge if it's needed :) then check duplicates

# %% [markdown]
# ## Hint: `After concat and merge, you should have 9450 rows with 53 columns`

# %% [markdown]
# ## Convert columns to the rows.
#
# hint: you can use the melt function from Pandas

# %%
data=

# %%
# Your dataframe shuold be like this:
data
# Out:
#                       REGION                            TYPE OF OFFENCE  \
# 0         Region Hovedstaden               Nature of the offence, total
# 1         Region Hovedstaden                          Penal Code, total
# 2         Region Hovedstaden                    Penal code, unspecified
# 3         Region Hovedstaden                     Sexual offenses, total
# 4         Region Hovedstaden                               Incest, etc.
# ...                      ...                                        ...
# 481945  Unknown municipality        Legislation on the national defence
# 481946  Unknown municipality   Legislation applying to public utilities
# 481947  Unknown municipality  Legislation on gambling, licencing, trade
# 481948  Unknown municipality              Any other special legislation
# 481949  Unknown municipality           Special legislation, unspecified
#
#           Time  Value
# 0       2007Q1  44860
# 1       2007Q1  38580
# 2       2007Q1      0
# ...

# %% [markdown]
# ## Convert the Time column to two columns: Year and the number of the quarter : like
# Time:2020Q2 -> year:2020 , quarter:2

# %% [markdown]
# So your dataframe will change to:

# %% [markdown]
# ![Screen Shot 2023-04-21 at 20.22.44.png](data:image/png;base64,...)

# %% [markdown]
# ## Show a horizontal barchart for number of the crimes (TYPE OF OFFENCE)

# %%
# Out:
# <Axes: ylabel='TYPE OF OFFENCE'>

# %% [markdown]
# # Create a linechart to show number of the 'Attempted homicide' and 'Homicide' from 2009 till 2019 (by two different lines)
#
# Attempted homicide -> red
# Homicide -> black  (such a meaningful color choice :) )

# %%
# Out:
# <Axes: xlabel='year', ylabel='Value'>

# %% [markdown]
# ## Now create a barplot to compare them together

# %%
# Out:
# <Axes: xlabel='year', ylabel='Value'>
