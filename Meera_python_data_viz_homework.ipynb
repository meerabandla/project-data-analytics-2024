# %%
# !pip install plotly

# %%
import pandas as pd
import plotly.express as px


C:\Users\bandl\OneDrive\Documents\redi\Crimes in Denmark till 2009.csv

# %%
url = "https://raw.githubusercontent.com/Bosmansc/redi/main/SampleSuperstore.csv"
df = pd.read_csv(url)
df
# Out:
#            Ship Mode    Segment        Country             City       State  \
# 0       Second Class   Consumer  United States        Henderson    Kentucky
# 1       Second Class   Consumer  United States        Henderson    Kentucky
# 2       Second Class  Corporate  United States      Los Angeles  California
# 3     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4     Standard Class   Consumer  United States  Fort Lauderdale     Florida
# ...              ...        ...            ...              ...         ...
# 9989    Second Class   Consumer  United States            Miami     Florida
# 9990  Standard Class   Consumer  United States       Costa Mesa  California
# 9991  Standard Class   Consumer  United States       Costa Mesa  California
# 9992  Standard Class   Consumer  United States       Costa Mesa  California
# 9993    Second Class   Consumer  United States      Westminster  California
#
# ...

# %%
# Create a state mapping dictionary
state_mapping = {
    'Alabama': 'AL',
    'Alaska': 'AK',
    'Arizona': 'AZ',
    'Arkansas': 'AR',
    'California': 'CA',
    'Colorado': 'CO',
    'Connecticut': 'CT',
    'Delaware': 'DE',
    'Florida': 'FL',
    'Georgia': 'GA',
    'Hawaii': 'HI',
    'Idaho': 'ID',
    'Illinois': 'IL',
    'Indiana': 'IN',
    'Iowa': 'IA',
    'Kansas': 'KS',
    'Kentucky': 'KY',
    'Louisiana': 'LA',
    'Maine': 'ME',
    'Maryland': 'MD',
    'Massachusetts': 'MA',
    'Michigan': 'MI',
    'Minnesota': 'MN',
    'Mississippi': 'MS',
    'Missouri': 'MO',
    'Montana': 'MT',
    'Nebraska': 'NE',
    'Nevada': 'NV',
    'New Hampshire': 'NH',
    'New Jersey': 'NJ',
    'New Mexico': 'NM',
    'New York': 'NY',
    'North Carolina': 'NC',
    'North Dakota': 'ND',
    'Ohio': 'OH',
    'Oklahoma': 'OK',
    'Oregon': 'OR',
    'Pennsylvania': 'PA',
    'Rhode Island': 'RI',
    'South Carolina': 'SC',
    'South Dakota': 'SD',
    'Tennessee': 'TN',
    'Texas': 'TX',
    'Utah': 'UT',
    'Vermont': 'VT',
    'Virginia': 'VA',
    'Washington': 'WA',
    'West Virginia': 'WV',
    'Wisconsin': 'WI',
    'Wyoming': 'WY'
}

# %% [markdown]
# ##### Questions
# Your company asks for a strategy for keeping inventory of items. How can you help them with insights and viz
#
# - we will give you some examples that you can look at but this is also an open question so feel free to add more graphs/numbers if you can
# - first focus on having the same numbers (using pandas) before starting on the visualisations
#
# - examples:
#   - which item category sold the most units (choose a graph to show this using plotly, for example a pie chart)
#   - among the different category of products which sub category has the most sales most, make a graph which is ordered both on category and sub category level
#   - analyze profit vs sales (for example using a scatter plot)
#   - which category gives the most profit?
#   - add a column: 'State_Code' based on the state_mapping dictionary (use map)
#   - get the profit and sales per state and plot it on a map of the US (hint: use px.choropleth)
#   - analyse the sales and profit by segment
#
#
#   You can use this guide for inspiration:
# https://www.kaggle.com/code/kanncaa1/plotly-tutorial-for-beginners

# %%
# example solution for question 1:
px.pie(df,values = 'Quantity',names ='Category',title = 'Quantity sold by category').show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
subcat_sales = df.groupby(['Category', 'Sub-Category'],as_index=false).Quantity.sum().reset_index()
print(subcat_sales)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-fa02987d3787> in <cell line: 1>()
# ----> 1 subcat_sales = df.groupby(['Category', 'Sub-Category'],as_index=false).Quantity.sum().reset_index()
#       2 print(subcat_sales)
#
# NameError: name 'df' is not defined
